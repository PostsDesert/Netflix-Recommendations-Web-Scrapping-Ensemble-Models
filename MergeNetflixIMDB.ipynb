# %%
import pandas as pd
from io import StringIO
import re

for_pd = StringIO()
with open('prize_dataset/movie_titles.csv') as movie_titles:
    for line in movie_titles:
        new_line = re.sub(r',', '|', line.rstrip(), count=2)
        print (new_line, file=for_pd)

for_pd.seek(0)

df = pd.read_csv(for_pd, sep='|', header=None, names=['MovieID', 'Year', 'Name'])
df

# load the movie_titles.csv file into a pandas dataframe
# df = pd.read_csv('prize_dataset/movie_titles.csv', encoding="ISO-8859-1", usecols=range(3), header=None, names=['MovieID', 'Year', 'Name'])

# print(df)
# Out:
#        MovieID    Year                                               Name
# 0            1  2003.0                                    Dinosaur Planet
# 1            2  2004.0                         Isle of Man TT 2004 Review
# 2            3  1997.0                                          Character
# 3            4  1994.0                       Paula Abdul's Get Up & Dance
# 4            5  2004.0                           The Rise and Fall of ECW
# ...        ...     ...                                                ...
# 17765    17766  2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767  2004.0                  Fidel Castro: American Experience
# 17767    17768  2000.0                                              Epoch
# 17768    17769  2003.0                                        The Company
# 17769    17770  2003.0                                       Alien Hunter
#
# [17770 rows x 3 columns]

# %%
import glob
import json
data = glob.glob('IMDB_data/data/*.json')
for file in data:
    file_name = os.path.basename(file).split('_')[0].replace("|", "/")
    print(file_name)
    with open(file, 'r') as f:
        json_data = json.load(f)
        imdbID = json_data['url']
        try:
            aggregateAvgRating = json_data['aggregateRating']['ratingValue']
        except:
            aggregateAvgRating = 0

        try:
            director = json_data['director'][0]['name']
        except:
            director = ''
        
        try:
            genre = ', '.join(json_data['genre'])
        except:
            genre = ''

        try:
            keywords = json_data['keywords']
        except:
            keywords = ''

        print(director)
            

        
        df.loc[df['Name'].str.split(',').str[0] == file_name, ['imdbID', 'AggregateAverageRating', 'Director', 'Genre', 'Keywords']] = [imdbID, aggregateAvgRating, director, genre, keywords]
        # df.loc[df['Name'].str.split(',').str[0] == file_name, 'imdbYear'] = year
# Out:
# Whisper Kill
# Christian I. Nyby II
# This Divided State
# Steven Greenstreet
# Under Siege 2: Dark Territory
# Geoff Murphy
# 3 Walls
# Nagesh Kukunoor
# Heart
# S.K. Nagendra Urs
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/csc-422-netflix-recommendations-web-scrapp-GnZiRDdD-py3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3185, in ndim(a)
#    3184 try:
# -> 3185     return a.ndim
#    3186 except AttributeError:
#
# AttributeError: 'list' object has no attribute 'ndim'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 37
#      31     keywords = []
#      33 print(director)
# ---> 37 df.loc[df['Name'].str.split(',').str[0] == file_name, ['imdbID', 'AggregateAverageRating', 'Director', 'Genre', 'Keywords']] = [imdbID, aggregateAvgRating, director, genre, keywords]
#      38 # df.loc[df['Name'].str.split(',').str[0] == file_name, 'imdbYear'] = year
#
# File ~/Library/Caches/pypoetry/virtualenvs/csc-422-netflix-recommendations-web-scrapp-GnZiRDdD-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:818, in _LocationIndexer.__setitem__(self, key, value)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/Library/Caches/pypoetry/virtualenvs/csc-422-netflix-recommendations-web-scrapp-GnZiRDdD-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1795, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1792 # align and set the values
#    1793 if take_split_path:
#    1794     # We have to operate column-wise
# -> 1795     self._setitem_with_indexer_split_path(indexer, value, name)
#    1796 else:
#    1797     self._setitem_single_block(indexer, value, name)
#
# File ~/Library/Caches/pypoetry/virtualenvs/csc-422-netflix-recommendations-web-scrapp-GnZiRDdD-py3.10/lib/python3.10/site-packages/pandas/core/indexing.py:1833, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1830 if isinstance(value, ABCDataFrame):
#    1831     self._setitem_with_indexer_frame_value(indexer, value, name)
# -> 1833 elif np.ndim(value) == 2:
#    1834     self._setitem_with_indexer_2d_value(indexer, value)
#    1836 elif len(ilocs) == 1 and lplane_indexer == len(value) and not is_scalar(pi):
#    1837     # We are setting multiple rows in a single column.
#
# File <__array_function__ internals>:200, in ndim(*args, **kwargs)
#
# File ~/Library/Caches/pypoetry/virtualenvs/csc-422-netflix-recommendations-web-scrapp-GnZiRDdD-py3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3187, in ndim(a)
#    3185     return a.ndim
#    3186 except AttributeError:
# -> 3187     return asarray(a).ndim
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.

# %%
print(df)
df.drop('imdbYear', axis=1)
# Out:
#        MovieID    Year                                               Name  \
# 0            1  2003.0                                    Dinosaur Planet
# 1            2  2004.0                         Isle of Man TT 2004 Review
# 2            3  1997.0                                          Character
# 3            4  1994.0                       Paula Abdul's Get Up & Dance
# 4            5  2004.0                           The Rise and Fall of ECW
# ...        ...     ...                                                ...
# 17765    17766  2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767  2004.0                  Fidel Castro: American Experience
# 17767    17768  2000.0                                              Epoch
# 17768    17769  2003.0                                        The Company
# 17769    17770  2003.0                                       Alien Hunter
#
#                   imdbID imdbYear  AggregateAverageRating         Director
# 0      /title/tt0389605/      NaN                     7.7
# 1                    NaN      NaN                     NaN              NaN
# 2      /title/tt0119448/      NaN                     7.7    Mike van Diem
# 3      /title/tt0277226/      NaN                     0.0  Jonathan Dayton
# 4      /title/tt0440751/      NaN                     0.0       Kevin Dunn
# ...                  ...      ...                     ...              ...
# 17765                NaN      NaN                     NaN              NaN
# 17766                NaN      NaN                     NaN              NaN
# 17767  /title/tt0282466/      NaN                     7.2      Vincent Lee
# 17768  /title/tt0335013/      NaN                     6.2    Robert Altman
# 17769  /title/tt0327409/      NaN                     5.1       Ron Krauss
#
# [17770 rows x 7 columns]
#        MovieID    Year                                               Name  \
# 0            1  2003.0                                    Dinosaur Planet
# 1            2  2004.0                         Isle of Man TT 2004 Review
# 2            3  1997.0                                          Character
# 3            4  1994.0                       Paula Abdul's Get Up & Dance
# 4            5  2004.0                           The Rise and Fall of ECW
# ...        ...     ...                                                ...
# 17765    17766  2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767  2004.0                  Fidel Castro: American Experience
# 17767    17768  2000.0                                              Epoch
# 17768    17769  2003.0                                        The Company
# 17769    17770  2003.0                                       Alien Hunter
#
#                   imdbID  AggregateAverageRating         Director
# 0      /title/tt0389605/                     7.7
# 1                    NaN                     NaN              NaN
# 2      /title/tt0119448/                     7.7    Mike van Diem
# 3      /title/tt0277226/                     0.0  Jonathan Dayton
# 4      /title/tt0440751/                     0.0       Kevin Dunn
# ...                  ...                     ...              ...
# 17765                NaN                     NaN              NaN
# 17766                NaN                     NaN              NaN
# 17767  /title/tt0282466/                     7.2      Vincent Lee
# 17768  /title/tt0335013/                     6.2    Robert Altman
# 17769  /title/tt0327409/                     5.1       Ron Krauss
#
# [17770 rows x 6 columns]

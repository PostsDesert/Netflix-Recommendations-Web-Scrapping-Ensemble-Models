# %%
import pandas as pd
from io import StringIO
import re

for_pd = StringIO()
with open('../prize_dataset/movie_titles.csv', encoding = 'ISO-8859-1') as movie_titles:
    for line in movie_titles:
        new_line = re.sub(r',', '|', line.rstrip(), count=2)
        print (new_line, file=for_pd)

for_pd.seek(0)

df = pd.read_csv(for_pd, sep='|', header=None, names=['MovieID', 'Year', 'Name'])
df
# Out:
#        MovieID    Year                                               Name
# 0            1  2003.0                                    Dinosaur Planet
# 1            2  2004.0                         Isle of Man TT 2004 Review
# 2            3  1997.0                                          Character
# 3            4  1994.0                       Paula Abdul's Get Up & Dance
# 4            5  2004.0                           The Rise and Fall of ECW
# ...        ...     ...                                                ...
# 17765    17766  2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767  2004.0                  Fidel Castro: American Experience
# 17767    17768  2000.0                                              Epoch
# 17768    17769  2003.0                                        The Company
# 17769    17770  2003.0                                       Alien Hunter
#
# [17770 rows x 3 columns]

# %%
import glob
import json
import os
import isodate


data = glob.glob('data/*.json')
for file in data:
    file_name = os.path.basename(file).split('_')[0].replace("|", "/")
    #print(file_name)
    with open(file, 'r') as f:
        json_data = json.load(f)
        imdbID = json_data['url']

        # get list of actors
        try:
            actors = [x['name'] for x in json_data['actor'] if x.get('name', '') != '']
            actors = ', '.join(actors)
        except:
            actors = None

        # get aggregate average rating
        try:
            aggregateAvgRating = json_data['aggregateRating']['ratingValue']
        except:
            aggregateAvgRating = None

        # get number of ratings
        try:
            numRatings = json_data['aggregateRating']['ratingCount']
        except:
            numRatings = None

        # get content rating
        contentRating = json_data.get('contentRating', '')

        # get creators
        try:
            creators = [x['name'] for x in json_data['creator'] if x.get('name', '') != '']
            creators = ', '.join(creators)
        except:
            creators = None

        # get description
        description = json_data.get('description', '')

        # get directors
        try:
            directors = [x['name'] for x in json_data['director'] if x.get('name', '') != '']
            directors = ', '.join(directors)
        except:
            directors = None

        # get duration
        try:
            iso_duration = json_data['duration']
            duration = isodate.parse_duration(iso_duration)
            duration = int(duration.total_seconds() / 60) # in minutes
        except:
            duration = None
            
        # get genre
        try:
            genre = ', '.join(json_data['genre'])
        except:
            genre = None

        # get keywords
        keywords = json_data.get('keywords')
            

        
        df.loc[df['Name'].str.split(',').str[0] == file_name, ['imdbID', 'AggregateAverageRating', 'NumRating', 'Directors', 'creators', 'Genre', 'Keywords', 'description', 'duration', 'actors', 'contentRating']] = \
                                                               [imdbID, aggregateAvgRating,  numRatings,  directors, creators, genre, keywords, description, duration, actors, contentRating]
        # df.loc[df['Name'].str.split(',').str[0] == file_name, 'imdbYear'] = year

# %%
df
df.to_csv('merge4.csv', index=False)

# %%
df
# Out:
#        MovieID    Year                                               Name
# 0            1  2003.0                                    Dinosaur Planet  \
# 1            2  2004.0                         Isle of Man TT 2004 Review
# 2            3  1997.0                                          Character
# 3            4  1994.0                       Paula Abdul's Get Up & Dance
# 4            5  2004.0                           The Rise and Fall of ECW
# ...        ...     ...                                                ...
# 17765    17766  2002.0  Where the Wild Things Are and Other Maurice Se...
# 17766    17767  2004.0                  Fidel Castro: American Experience
# 17767    17768  2000.0                                              Epoch
# 17768    17769  2003.0                                        The Company
# 17769    17770  2003.0                                       Alien Hunter
#
#                   imdbID  AggregateAverageRating  NumRating
# 0      /title/tt0389605/                     7.7      531.0  \
# 1                    NaN                     NaN        NaN
# 2      /title/tt0119448/                     7.7    11026.0
# 3      /title/tt0277226/                     NaN        NaN
# 4      /title/tt0440751/                     NaN        NaN
# ...                  ...                     ...        ...
# 17765                NaN                     NaN        NaN
# 17766                NaN                     NaN        NaN
# 17767  /title/tt0282466/                     7.2       23.0
# 17768  /title/tt0335013/                     6.2     6695.0
# 17769  /title/tt0327409/                     5.1     4624.0
#
#                             Directors
# 0                                None  \
# 1                                 NaN
# 2                       Mike van Diem
# 3      Jonathan Dayton, Valerie Faris
# 4                          Kevin Dunn
# ...                               ...
# 17765                             NaN
# 17766                             NaN
# 17767                     Vincent Lee
# 17768                   Robert Altman
# 17769                      Ron Krauss
#
#                                                 creators
# 0                                                         \
# 1                                                    NaN
# 2      Ferdinand Bordewijk, Laurens Geels, Mike van Diem
# 3                                                   None
# 4                                            Paul Heyman
# ...                                                  ...
# 17765                                                NaN
# 17766                                                NaN
# 17767                                        David Tzeng
# 17768                      Neve Campbell, Barbara Turner
# 17769                        J.S. Cardone, Boaz Davidson
#
#                                 Genre
# 0      Documentary, Animation, Family  \
# 1                                 NaN
# 2               Crime, Drama, Mystery
# 3                               Music
# 4                  Documentary, Sport
# ...                               ...
# 17765                             NaN
# 17766                             NaN
# 17767          Action, Drama, Fantasy
# 17768           Drama, Music, Romance
# 17769       Action, Adventure, Sci-Fi
#
#                                                 Keywords
# 0      feathered dinosaur,natural disaster,cg animati...  \
# 1                                                    NaN
# 2      gunfight,street shootout,police shootout,fianc...
# 3      tap dancing,music video,20th century,1980s,pop...
# 4      eastern championship wrestling,drinking beer,s...
# ...                                                  ...
# 17765                                                NaN
# 17766                                                NaN
# 17767                                               None
# 17768  snapped achilles trendon,female nudity,nudity,...
# 17769     alien,elevator,alien invasion,u boat,womanizer
#
#                                              description  duration
# 0      A four-episode animated series charting the ad...       NaN  \
# 1                                                    NaN       NaN
# 2      Jacob Katadreuffe lives mute with his mother, ...     122.0
# 3      Paula Abdul&apos;s music video collection with...      35.0
# 4      A documentary on the rise and fall of cult wre...     360.0
# ...                                                  ...       ...
# 17765                                                NaN       NaN
# 17766                                                NaN       NaN
# 17767  The story takes place in the distant future, w...       NaN
# 17768  A young ballet dancer is poised to become the ...     112.0
# 17769  An alien black box is found in the South Pole,...      92.0
#
#                                                   actors contentRating
# 0      Christian Slater, Ana Claudia Talancón, Bruno ...     Not Rated
# 1                                                    NaN           NaN
# 2      Pavlik Jansen op de Haar, Jan Decleir, Fedja v...             R
# 3                    Paula Abdul, Bill Bohl, Dee Caspary
# 4        Abdullah the Butcher, Donna Adamo, Bill Alfonso         TV-MA
# ...                                                  ...           ...
# 17765                                                NaN           NaN
# 17766                                                NaN           NaN
# 17767             Ho-Sung Pak, T.J. Storm, Robert Alonzo
# 17768      Neve Campbell, James Franco, Malcolm McDowell         PG-13
# 17769              James Spader, Janine Eser, John Lynch             R
#
# [17770 rows x 14 columns]

# %%
import subprocess

CMD = '''
on run argv
  display notification (item 2 of argv) with title (item 1 of argv)
end run
'''

def notify(title, text):
  subprocess.call(['osascript', '-e', CMD, title, text])

# Example uses:
notify("Your script done", "Heres an alert")
